# %% [markdown]
# <a href="https://colab.research.google.com/github/ilafmakke/traininf-data-frame/blob/main/EDA__COURSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# #EDA COURSE
# ```
#
# # New Section

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Get the list of uploaded filenames
uploaded_filenames = list(uploaded.keys())
# Print the list of filenames
print(uploaded_filenames)
uploaded_csv_content = uploaded[uploaded_filenames[0]]
data = pd.read_csv(uploaded_filenames[0])
print("CSV file read successfully.")
# Out:
#      <input type="file" id="files-73697f87-3b3a-492d-8691-fe6d127f3ca7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73697f87-3b3a-492d-8691-fe6d127f3ca7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#type of eah colummn
df=data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
#last 10 rows
df.tail(10)
# Out:
#      state  account length  area code phone number international plan  \
# 3323    IN             117        415     362-5899                 no
# 3324    WV             159        415     377-1164                 no
# 3325    OH              78        408     368-8555                 no
# 3326    OH              96        415     347-6812                 no
# 3327    SC              79        415     348-3830                 no
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3323              no                      0              118.4
# 3324              no                      0              169.8
# ...

# %%
df.sort_values(by='total day calls',ascending=False)
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 2392    WY              90        510     400-8069                 no
# 1057    WV              86        415     332-2258                 no
# ...    ...             ...        ...          ...                ...
# 692     NE              82        408     343-2741                 no
# 1989    MT             124        415     420-5652                 no
# 1144    NH             155        408     353-6300                 no
# 1397    VT             101        510     413-7655                 no
# 1345    SD              98        415     392-2555                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
#nb of rows and columns
df.shape
# Out:
# (3333, 21)

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
#df['state']or df[df.columns[0]] same result
df.columns[0]
# Out:
# 'state'

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=['object','bool'])
#is used to generate a summary of the DataFrame df for columns that contain categorical data (objects and booleans).
# Out:
#        state phone number international plan voice mail plan  churn
# count   3333         3333               3333            3333   3333
# unique    51         3333                  2               2      2
# top       WV     382-4657                 no              no  False
# freq     106            1               3010            2411   2850

# %%
#is used to convert the data type of the 'churn' column in a pandas DataFrame df to integers ('int').
df['churn']=df['churn'].astype('int')
df['churn']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %%
#count the nb of zero and one
df['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
df['churn'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: churn, dtype: float64

# %%
df.sort_values(by=['total day calls','total night calls'],ascending=[False,True])
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 315     MA              39        408     332-2462                 no
# 1057    WV              86        415     332-2258                 no
# ...    ...             ...        ...          ...                ...
# 692     NE              82        408     343-2741                 no
# 1989    MT             124        415     420-5652                 no
# 1144    NH             155        408     353-6300                 no
# 1345    SD              98        415     392-2555                 no
# 1397    VT             101        510     413-7655                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['total day minutes'].mean()
# Out:
# 179.77509750975094

# %%
df[df['churn'] == 1]['total day minutes'].mean()
# Out:
# 206.91407867494823

# %%
df[df['churn'] == 1].mean()
# Out:
# <ipython-input-33-d5c8426bb6af>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['churn'] == 1].mean()
# account length            102.664596
# area code                 437.817805
# number vmail messages       5.115942
# total day minutes         206.914079
# total day calls           101.335404
# total day charge           35.175921
# total eve minutes         212.410145
# total eve calls           100.561077
# total eve charge           18.054969
# total night minutes       205.231677
# total night calls         100.399586
# total night charge          9.235528
# total intl minutes         10.700000
# total intl calls            4.163561
# total intl charge           2.889545
# customer service calls      2.229814
# ...

# %%
df.loc[:5,['international plan','state']]
# Out:
#   international plan state
# 0                 no    KS
# 1                 no    OH
# 2                 no    NJ
# 3                yes    OH
# 4                yes    OK
# 5                yes    AL

# %%
df.iloc[-1:]
# Out:
#      state  account length  area code phone number international plan  \
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 3332              22.6                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 3332                3.7                       0      0
#
# [1 rows x 21 columns]

# %%
df[-1:]
# Out:
#      state  account length  area code phone number international plan  \
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 3332              22.6                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 3332                3.7                       0      0
#
# [1 rows x 21 columns]

# %%
apply and map sect

# %% [markdown]
# # New Section

# %%
d={'yes':True, 'no':False}
df['international plan']=df['international plan'].map(d)
df['international plan']
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331     True
# 3332    False
# Name: international plan, Length: 3333, dtype: bool

# %%
import  numpy as np
df.groupby(['churn'])['total day minutes','total eve minutes'].agg([np.mean,np.std,np.min])
# Out:
# <ipython-input-10-f99ac8e24375>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['churn'])['total day minutes','total eve minutes'].agg([np.mean,np.std,np.min])
#       total day minutes                 total eve minutes
#                    mean        std amin              mean        std  amin
# churn
# False        175.175754  50.181655  0.0        199.043298  50.292175   0.0
# True         206.914079  68.997792  0.0        212.410145  51.728910  70.9

# %%
df=df.replace({'voice mail plan':d})

# %% [markdown]
# # New Section

# %%
pd.crosstab(df['churn'],df['international plan'])
# Out:
# international plan  False  True
# churn
# False                2664    186
# True                  346    137

# %%
pd.crosstab(df['churn'],df['international plan'], normalize=True)
# Out:
# international plan    False     True
# churn
# False               0.79928  0.055806
# True                0.10381  0.041104

# %%
df.pivot_table(['total day calls','total eve calls','total night calls'],['area code'],aggfunc='mean')
# Out:
#            total day calls  total eve calls  total night calls
# area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190
